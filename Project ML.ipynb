# %%
import pandas as pd

# %%
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv", na_values = missing_values)

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
df.shape
# Out:
# (23486, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23486 non-null  int64
#  1   Clothing ID              23486 non-null  int64
#  2   Age                      23486 non-null  int64
#  3   Title                    19676 non-null  object
#  4   Review Text              22641 non-null  object
#  5   Rating                   23486 non-null  int64
#  6   Recommended IND          23486 non-null  int64
#  7   Positive Feedback Count  23486 non-null  int64
#  8   Division Name            23472 non-null  object
#  9   Department Name          23472 non-null  object
#  10  Class Name               23472 non-null  object
# dtypes: int64(6), object(5)
# memory usage: 2.0+ MB

# %%
df.describe()
# Out:
#          Unnamed: 0   Clothing ID           Age        Rating  \
# count  23486.000000  23486.000000  23486.000000  23486.000000
# mean   11742.500000    918.118709     43.198544      4.196032
# std     6779.968547    203.298980     12.279544      1.110031
# min        0.000000      0.000000     18.000000      1.000000
# 25%     5871.250000    861.000000     34.000000      4.000000
# 50%    11742.500000    936.000000     41.000000      5.000000
# 75%    17613.750000   1078.000000     52.000000      5.000000
# max    23485.000000   1205.000000     99.000000      5.000000
#
#        Recommended IND  Positive Feedback Count
# count     23486.000000             23486.000000
# mean          0.822362                 2.535936
# std           0.382216                 5.702202
# min           0.000000                 0.000000
# 25%           1.000000                 0.000000
# 50%           1.000000                 1.000000
# 75%           1.000000                 3.000000
# ...

# %%
#Deleting columns that doesn't add any value to our analysis
df = df.drop(['Unnamed: 0','Title','Clothing ID'],axis=1)

# %%
df.isna().sum()
# Out:
# Age                          0
# Review Text                845
# Rating                       0
# Recommended IND              0
# Positive Feedback Count      0
# Division Name               14
# Department Name             14
# Class Name                  14
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 887

# %%
## Dropping the records where review text is null
df = df[~df['Review Text'].isnull()]

# %%
df.isna().sum()
# Out:
# Age                         0
# Review Text                 0
# Rating                      0
# Recommended IND             0
# Positive Feedback Count     0
# Division Name              13
# Department Name            13
# Class Name                 13
# dtype: int64

# %%
from scipy import stats

# %%
Division_name_mode=df["Division Name"].mode()
print(Division_name_mode)
# Out:
# 0    General
# Name: Division Name, dtype: object

# %%
Department_name_mode=df["Department Name"].mode()
print(Department_name_mode)
# Out:
# 0    Tops
# Name: Department Name, dtype: object

# %%
Class_name_mode=df["Class Name"].mode()
print(Class_name_mode)
# Out:
# 0    Dresses
# Name: Class Name, dtype: object

# %%
def fillna(df,col):
    return df[col].fillna(df[col].mode()[0],inplace=True)

# %%
missing_data=["Division Name","Department Name","Class Name"]

# %%
for i in missing_data:
    fillna(df,i)

# %%
df.isna().sum()
# Out:
# Age                        0
# Review Text                0
# Rating                     0
# Recommended IND            0
# Positive Feedback Count    0
# Division Name              0
# Department Name            0
# Class Name                 0
# dtype: int64

# %%
df.head(25)
# Out:
#     Age                                        Review Text  Rating  \
# 0    33  Absolutely wonderful - silky and sexy and comf...       4
# 1    34  Love this dress!  it's sooo pretty.  i happene...       5
# 2    60  I had such high hopes for this dress and reall...       3
# 3    50  I love, love, love this jumpsuit. it's fun, fl...       5
# 4    47  This shirt is very flattering to all due to th...       5
# 5    49  I love tracy reese dresses, but this one is no...       2
# 6    39  I aded this in my basket at hte last mintue to...       5
# 7    39  I ordered this in carbon for store pick up, an...       4
# 8    24  I love this dress. i usually get an xs but it ...       5
# 9    34  I'm 5"5' and 125 lbs. i ordered the s petite t...       5
# 10   53  Dress runs small esp where the zipper area run...       3
# 11   39  This dress is perfection! so pretty and flatte...       5
# 12   53  More and more i find myself reliant on the rev...       5
# ...

# %%
import seaborn as sns

# %%
train['word_count'] = train['Review Text'].apply(lambda x: len(str(x).split(" 
"))) 
train[['Review Text','word_count']].head()
# Out:
#   Input In [52]
#     train['word_count'] = train['Review Text'].apply(lambda x: len(str(x).split("
#                                                                                   ^
# SyntaxError: EOL while scanning string literal
